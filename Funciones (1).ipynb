# %%
def bienvenida():
     print('¡Bienvenido a Python!')
     return
print(type(bienvenida))
bienvenida()
#print(bienvenida2())#Descomentar para ver que tiene que estar antes la declaración
'''Argumentos de  una función'''
def bienvenida2(nombre):
     print('¡Bienvenido a Python', nombre + '!')
     return
print('****Función con Argumentos****')
bienvenida2('Rufino')

print('***Tipos Argumentos***')
def bienvenida3(nombre, apellido):
     print('¡Bienvenido a Python', nombre, apellido + '!')
     return
print('***Argumentos Posicionales***')
bienvenida3('Rufino', 'Prieto')
print('***Argumentos Nominales***')
bienvenida3(apellido = 'Prieto', nombre = 'Rufino')

print('***Arguemntos por defecto***')
def bienvenida4(nombre, lenguaje = 'Python'):
     print('¡Bienvenido a', lenguaje, nombre + '!')
     return
bienvenida4('Rufino')
bienvenida4('Rufino','.NET')

print('***Num Params***')
def menu(*platos):
     print('Hoy tenemos: ', end='')
     for plato in platos:
         print(plato, end=', ')
     return

menu('pasta', 'pizza', 'ensalada')

 
print('***documentación de funciones***')

def area_triangulo(base, altura):
    '''Función que calcula el área de un triángulo.
Parámetros:
 - base: Un número real con la base del triángulo.
 - altura: Un número real con la altura del triángulo.
Salida:
 Un número real con el área del triángulo de base y altura especificadas.
'''
    return base * altura / 2

help(area_triangulo)
# Out:
# <class 'function'>
# ¡Bienvenido a Python!
# ****Función con Argumentos****
# ¡Bienvenido a Python Rufino!
# ***Tipos Argumentos***
# ***Argumentos Posicionales***
# ¡Bienvenido a Python Rufino Prieto!
# ***Argumentos Nominales***
# ¡Bienvenido a Python Rufino Prieto!
# ***Arguemntos por defecto***
# ¡Bienvenido a Python Rufino!
# ¡Bienvenido a .NET Rufino!
# ***Num Params***
# Hoy tenemos: pasta, pizza, ensalada, ***documentación de funciones***
# Help on function area_triangulo in module __main__:
#
# area_triangulo(base, altura)
#     Función que calcula el área de un triángulo.
#     Parámetros:
#      - base: Un número real con la base del triángulo.
#      - altura: Un número real con la altura del triángulo.
#     Salida:
#      Un número real con el área del triángulo de base y altura especificadas.

# %%
#Funciones built-in
#Python dispone de algunas funciones nativas que se cargan cuando se inicia el intérprete. 
#Por ejemplo la función max devuelve el mayor valor numérico de una lista de números
max([10,35,5,110,48,30,112,98,87])
min([10,35,5,110,48,30,112,98,87])
a = max([10,5,8])
b = min([10,5,8])
h = (a - b)/10
print(h)
round(3.141592653589793, 6)
round(3.141592653589793, 2)
# Out:
# 0.5
# 3.14

# %%
#La función Print
print("Hola mundo")
#lista de argumentos
print("hola", "mundo", 5, 8, [1,2,3])
#separador
print(20,30,"python", sep=",")
print("Hola", 90, 80, sep=" -- ")
print("Hola", 90, 80, sep=" \u21e8 ")
print("Hola", "mundo", sep=" \U0001F600 ")
print(20,30,"python") # sin cambiar el argumento end 
print("hola")

#Cambiando el argumento end:

print(20,30,"python", end="\n\n\t") # utilizando un doble salto de línea + tab
print("hola")
# Out:
# Hola mundo
# hola mundo 5 8 [1, 2, 3]
# 20,30,python
# Hola -- 90 -- 80
# Hola ⇨ 90 ⇨ 80
# Hola 😀 mundo
# 20 30 python
# hola
# 20 30 python
#
# 	hola

# %%
#Función input
#la función input permite obtener entrada por teclado, con la finalidad de tomar información proporcionada por el usuario. La sintaxis de input es:

#var = input(prompt)
#Donde prompt es el mensaje que se muestra al usuario 
#al momento que se le solicita la información, var es la variable en la cual se almacena lo que el usuario ingresa hasta que presiona la tecla Enter.


nombre = input("Ingrese su nombre: ")
print("Hola", nombre, "bienvenido")
# Out:
# Ingrese su nombre:  Luis
# Hola Luis bienvenido

# %%
#Es importante tener en cuenta que la función input devuelve siempre un valor de tipo string
# No podemos sumar un string con un entero
n = input("Ingrese un número: ")
print(n + 10)
# Out:
# Ingrese un número:  1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       1 #Es importante tener en cuenta que la función input devuelve siempre un valor de tipo string
#       2 # No podemos sumar un string con un entero
#       3 n = input("Ingrese un número: ")
# ----> 4 print(n + 10)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Aquí n+n+n corresponde a concatenar la cadena "12", en lugar de sumar los valores numéricos.
n = input("Ingrese un número: ")
print(n + n + n)

# %%
# Ahora n+n+n si corresponde a sumar dichos valores numéricamente
n = float( input("Ingrese un número: ") )
print(n + n + n)

# %% [markdown]
# ### Funciones definidas por el usuario
# def saluda(nombre):
#     s = "Hola " + nombre + ", bienvenido."
#     return s
# print(saluda("Jorge"))

# %%
##Funciones definida por el usuario
def saluda(nombre):
    s = "Hola " + nombre + ", bienvenido."
    return s
print(saluda("Francesco"))
# Out:
# Hola Francesco, bienvenido.

# %%
def espar(n):
    if n%2 == 0:
        s = True
    else:
        s = False
    return s
print(espar(2))
print(espar(5))
print(espar(10))
# Out:
# True
# False
# True

# %%
#+argumentos
def mayor(a,b):
    m = a
    if a < b:
        m = b
    return m
print( mayor(50,30) )
print( mayor(1100,3050) )
# Out:
# 50
# 3050

# %%
#¿Pueden las funciones en Python devolver más de un valor? ¡Claro! Hace falta nada más separar con comas los valores a devolver.
def calcula_rectangulo(b,h):
    A = b*h
    P = 2*b + 2*h
    return A, P
print( calcula_rectangulo(10,5) )
print( calcula_rectangulo(50,15) )
# Out:
# (50, 30)
# (750, 130)

# %%
#También es posible guardar/asignar los valores devueltos por la función en variables:

area1, perimetro1 = calcula_rectangulo(100, 20)
print("Área: {0}\nPerímetro: {1}".format(area1, perimetro1))
# Out:
# Área: 2000
# Perímetro: 240

# %%
#Funciones con una cantidad de parámetros indeterminada
#al nombre del parámetro le anteponemos un asterisco, esto le indica a Python que la cantidad de argumentos de entrada es indeterminada
def promedio(*numeros):
    suma = 0
    k = 0
    for n in numeros:
        suma += n
        k += 1
    return suma/k
print(promedio(10,5))
print(promedio(10,50,40,80,20,100))
print(promedio(5,15,10,5))
# Out:
# 7.5
# 50.0
# 8.75

# %%
#Funciones y los argumentos con nombre
#se puede mandar a llamar pasándo los argumentos de manera posicional, es decir, en el orden que fueron definidos en la función, 
#o bien, haciendo uso del nombre del parámetro correspondiente al argumento que se introduce

def cuenta_cuantas(frase, letra):
    k = 0
    for car in frase:
        if car is letra:
            k += 1
    return k
print( cuenta_cuantas("hola mundo", "o") )
print( cuenta_cuantas(frase="hola mundo", letra="o") )
print( cuenta_cuantas(letra="o", frase="hola mundo") )
# Out:
# 2
# 2
# 2

# %%
#En la definición de funciones es posible también especificar que se pasarán ciertos argumentos
#con nombre sin necesidad de escribirlos de manera explícita. Observe la siguiente función:
def muestra_puntos(**personas):
    for persona in personas.items():
        print(persona[0] + " tiene " + str(persona[1]) + " puntos")
muestra_puntos(Jorge=8, Paty=10)
print(30*"=")
muestra_puntos(Ana=6, Carlos=9, Victor=4, Daniela=8)

'''
Vea que la definición de la función muestra_puntos incluye un parámetro llamado **personas, 
esos dos asteriscos antes del nombre del parámetro, indican que no se tiene predeterminado el número de argumentos que se pasarán, pero además, 
indica que cada argumento a introducir deberá ser un argumento con nombre. Dentro del cuerpo de la función el parámetro **personas 
es un diccionario cuyas claves son los nombres de los argumentos y los valores corresponden a cada valor asignado al argumento.
'''
# Out:
# Jorge tiene 8 puntos
# Paty tiene 10 puntos
# ...
# Ana tiene 6 puntos
# Carlos tiene 9 puntos
# Victor tiene 4 puntos
# Daniela tiene 8 puntos
# '\nVea que la definición de la función muestra_puntos incluye un parámetro llamado **personas, \nesos dos asteriscos antes del nombre del parámetro, indican que no se tiene predeterminado el número de argumentos que se pasarán, pero además, \nindica que cada argumento a introducir deberá ser un argumento con nombre. Dentro del cuerpo de la función el parámetro **personas \nes un diccionario cuyas claves son los nombres de los argumentos y los valores corresponden a cada valor asignado al argumento.\n'

# %%
print(100*"=")
