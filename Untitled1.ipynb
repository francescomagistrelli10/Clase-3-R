# %%
frutas = ["pera"," manzana", "naranja", "uva", "cereza"]
i = 0 
while i < len(frutas):
    if i != 1: 
        print(frutas[i])
    i+= 1
frutas[1] = "piña"
print("Lista modificada",frutas)
# Out:
# pera
# naranja
# uva
# cereza
# Lista modificada ['pera', 'piña', 'naranja', 'uva', 'cereza']

# %%
a = {'nombre':'Rufino', 'despacho': 218, 'email':'rufino.prieto@ufv.es'}
len(a)
# Out:
# 3

# %%
'email' in a
# Out:
# True

# %%
a.keys()
# Out:
# dict_keys(['nombre', 'despacho', 'email'])

# %%
 a.values()
# Out:
# dict_values(['Rufino', 218, 'rufino.prieto@ufv.es'])

# %%
a.items()
# Out:
# dict_items([('nombre', 'Rufino'), ('despacho', 218), ('email', 'rufino.prieto@ufv.es')])

# %%
def bienvenida(nombre, lenguaje = 'Python'):
    print('¡Bienvenido a', lenguaje, nombre + '!')
    return
    
    bienvenida('Rufino')

# %%
def menu(*platos):
    print('Hoy tenemos: ', end='')
    for plato in platos:
        print(plato, end=', ')
menu('pasta', 'pizza', 'ensalada')
# Out:
# Hoy tenemos: pasta, pizza, ensalada,

# %%
a = 6
print(a)
# Out:
# 6
